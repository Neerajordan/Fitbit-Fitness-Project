# %% [markdown]
# Importing required libraries for data analysis and visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Load related dataset

# %%
df = pd.read_csv('/content/daily_stats_data.csv')

# %%
df.head(5)
# Out:
#            id activity_date  daily_average_heartrate  total_steps  \
# 0  1503960366    2016-04-12                      NaN        13162
# 1  1503960366    2016-04-13                      NaN        10735
# 2  1503960366    2016-04-14                      NaN        10460
# 3  1503960366    2016-04-15                      NaN         9762
# 4  1503960366    2016-04-16                      NaN        12669
#
#    total_distance  tracker_distance  logged_activities_distance  \
# 0            8.50              8.50                         0.0
# 1            6.97              6.97                         0.0
# 2            6.74              6.74                         0.0
# 3            6.28              6.28                         0.0
# 4            8.16              8.16                         0.0
#
#    very_active_distance  moderately_active_distance  light_active_distance  \
# 0                  1.88                        0.55                   6.06
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          940 non-null    int64
#  1   activity_date               940 non-null    object
#  2   daily_average_heartrate     334 non-null    float64
#  3   total_steps                 940 non-null    int64
#  4   total_distance              940 non-null    float64
#  5   tracker_distance            940 non-null    float64
#  6   logged_activities_distance  940 non-null    float64
#  7   very_active_distance        940 non-null    float64
#  8   moderately_active_distance  940 non-null    float64
#  9   light_active_distance       940 non-null    float64
#  10  sedentary_active_distance   940 non-null    float64
#  11  very_active_minutes         940 non-null    int64
#  12  fairly_active_minutes       940 non-null    int64
# ...

# %%
df.isna().sum()
# Out:
# id                              0
# activity_date                   0
# daily_average_heartrate       606
# total_steps                     0
# total_distance                  0
# tracker_distance                0
# logged_activities_distance      0
# very_active_distance            0
# moderately_active_distance      0
# light_active_distance           0
# sedentary_active_distance       0
# very_active_minutes             0
# fairly_active_minutes           0
# lightly_active_minutes          0
# sedentary_minutes               0
# calories                        0
# total_minutes_asleep          530
# total_sleep_records           530
# total_time_in_bed             530
# bmi                           873
# weight_kg                     873
# weight_pounds                 873
# dtype: int64

# %%
df.dtypes
# Out:
# id                              int64
# activity_date                  object
# daily_average_heartrate       float64
# total_steps                     int64
# total_distance                float64
# tracker_distance              float64
# logged_activities_distance    float64
# very_active_distance          float64
# moderately_active_distance    float64
# light_active_distance         float64
# sedentary_active_distance     float64
# very_active_minutes             int64
# fairly_active_minutes           int64
# lightly_active_minutes          int64
# sedentary_minutes               int64
# calories                        int64
# total_minutes_asleep          float64
# total_sleep_records           float64
# total_time_in_bed             float64
# bmi                           float64
# weight_kg                     float64
# weight_pounds                 float64
# dtype: object

# %% [markdown]
# **Statistics & Data Vizualization**

# %% [markdown]
# 1.  Descriptive Numeric Analysis

# %%
df.describe()
# Out:
#                  id  daily_average_heartrate   total_steps  total_distance  \
# count  9.400000e+02               334.000000    940.000000      940.000000
# mean   4.855407e+09                75.974042   7637.910638        5.489702
# std    2.424805e+09                10.340623   5087.150742        3.924606
# min    1.503960e+09                57.870000      0.000000        0.000000
# 25%    2.320127e+09                67.512500   3789.750000        2.620000
# 50%    4.445115e+09                75.220000   7405.500000        5.245000
# 75%    6.962181e+09                81.932500  10727.000000        7.712500
# max    8.877689e+09               107.720000  36019.000000       28.030000
#
#        tracker_distance  logged_activities_distance  very_active_distance  \
# count        940.000000                  940.000000            940.000000
# mean           5.475351                    0.108128              1.502681
# ...

# %% [markdown]
# 2. Correlation Analysis

# %%
num_column = df.select_dtypes(include='number')
matrix = num_column.corr()
matrix
# Out:
#                                   id  daily_average_heartrate  total_steps  \
# id                          1.000000                 0.025742     0.185721
# daily_average_heartrate     0.025742                 1.000000     0.011922
# total_steps                 0.185721                 0.011922     1.000000
# total_distance              0.241000                 0.006960     0.985369
# tracker_distance            0.238816                -0.006357     0.984822
# logged_activities_distance  0.187965                 0.295305     0.181850
# very_active_distance        0.308691                 0.019929     0.740115
# moderately_active_distance  0.026665                -0.013992     0.507105
# light_active_distance       0.019629                -0.006604     0.692208
# sedentary_active_distance  -0.015698                 0.009890     0.070505
# very_active_minutes         0.303608                -0.055824     0.667079
# ...

# %% [markdown]
# USERS WITH MOST ACTIVE AND LESS ACTIVE MINUTES

# %%
most_active_users = df.sort_values(by=['very_active_minutes', 'fairly_active_minutes'], ascending=False).head(10)[['id', 'activity_date','very_active_minutes', 'fairly_active_minutes']]
most_active_users
# Out:
#              id activity_date  very_active_minutes  fairly_active_minutes
# 579  5577150313    2016-04-24                  210                     65
# 585  5577150313    2016-04-30                  207                     45
# 572  5577150313    2016-04-17                  200                     37
# 586  5577150313    2016-05-01                  194                     72
# 50   1624580081    2016-05-01                  186                     63
# 571  5577150313    2016-04-16                  184                     56
# 827  8378563200    2016-04-21                  137                     16
# 771  8053475328    2016-04-15                  132                      8
# 780  8053475328    2016-04-24                  129                     33
# 779  8053475328    2016-04-23                  125                     14

# %%
less_active_users = df[(df['very_active_minutes'] > 0) & (df['fairly_active_minutes'] > 0)]
less_active_users = less_active_users.sort_values(by=['very_active_minutes', 'fairly_active_minutes']).head(10)[['id', 'activity_date', 'very_active_minutes', 'fairly_active_minutes']]
less_active_users
# Out:
#              id activity_date  very_active_minutes  fairly_active_minutes
# 393  4319703577    2016-04-24                    1                      5
# 135  1927972279    2016-04-24                    1                      6
# 271  2873212765    2016-04-18                    1                      6
# 286  2873212765    2016-05-03                    1                      6
# 82   1644430081    2016-05-02                    1                      7
# 252  2347167796    2016-04-17                    1                      7
# 508  4702921684    2016-04-15                    1                      8
# 519  4702921684    2016-04-26                    1                      8
# 383  4319703577    2016-04-14                    1                      9
# 387  4319703577    2016-04-18                    1                      9

# %% [markdown]
#  **DATA VISUALISATION**

# %% [markdown]
# 1. Heat Map

# %%
total_corr = df[["total_steps", "total_distance", "tracker_distance", "logged_activities_distance","very_active_distance", "moderately_active_distance", "light_active_distance", "sedentary_active_distance", "very_active_minutes", "fairly_active_minutes", "lightly_active_minutes", "sedentary_minutes", "total_minutes_asleep", "total_time_in_bed", "calories"]].corr()

# plotting the heatmap
fig, ax = plt.subplots(figsize=(15,8))
sns.heatmap(total_corr, annot=True, fmt = '.2f', cmap="viridis")
plt.title("COORELATION HEATMAP OF DAILY STATS")
# Out:
# Text(0.5, 1.0, 'COORELATION HEATMAP OF DAILY STATS')

# %% [markdown]
# 2. Scatter Plot

# %%
fig1 = px.scatter(df, x='total_distance', y='total_steps', title='Scatter Plot between Steps and Distance',
                  labels={'total_distance': 'Total Distance', 'total_steps': 'Total Steps'},
                  color_discrete_sequence=['darkviolet'])
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 3. Bar Chart

# %%
fig1 = px.bar(df, x='activity_date', y='daily_average_heartrate',
              title='Bar Plot: Activity Date vs. Daily Average Heartrate',
              labels={'activity_date': 'Activity Date', 'daily_average_heartrate': 'Daily Average Heartrate'},
              color_discrete_sequence=['slateblue'])
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 4. Pair Plot

# %%
fig = px.scatter_matrix(df, dimensions=['total_distance', 'tracker_distance', 'total_steps'],
                        title='Pair Plot',
                        labels={'total_distance': 'Total Distance', 'tracker_distance': 'Tracker Distance','total_steps': 'Total Steps'},
                        color_discrete_sequence=['orange'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
